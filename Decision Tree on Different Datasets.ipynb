# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix 
from sklearn import tree

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
def change(x):
    if x == -1:
        return 0
    return x

# %%
df4= pd.read_csv('data4.csv', header= None)

# %%
df4.head()
# Out:
#    0  1  2  3
# 0  1  1  1  1
# 1  1  1  2  1
# 2  1  1  3  1
# 3  1  1  5  1
# 4  1  1  7  1

# %%
df4.shape
# Out:
# (161, 4)

# %%
x = dict(df4[3].value_counts())
print(x)
# Out:
# {-1: 93, 1: 68}

# %%
df4[3] = df4[3].apply(lambda x:chng(x))
df4[3].unique()
# Out:
# array([1, 0], dtype=int64)

# %%
X_train4, X_test4, y_train4, y_test4 = train_test_split(df4[[0,1,2]],df4[3],test_size=0.3)

# %%
model4 = tree.DecisionTreeClassifier(criterion="entropy")
model4.fit(X_train4,y_train4)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
model4.score(X_test4,y_test4)
# Out:
# 0.8979591836734694

# %%
model4.feature_importances_
# Out:
# array([0.38224504, 0.42888816, 0.1888668 ])

# %%
y_predicted4 = model4.predict(X_test4)

# %%
# Number of features seen during fit
model4.n_features_in_
# Out:
# 3

# %%
# The number of classes:
model4.n_classes_
# Out:
# 2

# %%
print(classification_report(y_test4,y_predicted4))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.89      0.91        28
#            1       0.86      0.90      0.88        21
#
#     accuracy                           0.90        49
#    macro avg       0.89      0.90      0.90        49
# weighted avg       0.90      0.90      0.90        49

# %%
cm4 = confusion_matrix(y_test4,y_predicted)
sns.heatmap(cm4, annot=True)
# Out:
# <AxesSubplot:>

# %%
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(model4, feature_names=[0,1,2], filled=True)

# %% [markdown]
# # Data 5:

# %%
df5= pd.read_csv('data5.csv', header= None)

# %%
df5.head()
# Out:
#         0        1        2  3
# 0 -48.780  -5.5458   2.4477 -1
# 1 -48.612 -39.2840  12.7950 -1
# 2 -46.885 -16.0340  -8.8351  1
# 3 -46.384 -40.1080 -17.2380  1
# 4 -46.007 -19.0540 -17.6810  1

# %%
df5.shape
# Out:
# (209, 4)

# %%
x = dict(df5[3].value_counts())
print(x)
# Out:
# {1: 109, -1: 100}

# %%
df5[3] = df5[3].apply(lambda x: change(x))
df5[3].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
X_train5, X_test5, y_train5, y_test5 = train_test_split(df5[[0,1,2]],df5[3],test_size=0.3)

# %%
model5 = tree.DecisionTreeClassifier(criterion="entropy")

# %%
model5.fit(X_train5,y_train5)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
model5.score(X_test5,y_test5)
# Out:
# 0.6507936507936508

# %%
model5.feature_importances_
# Out:
# array([0.33694057, 0.30510019, 0.35795925])

# %%
y_predicted5 = model5.predict(X_test5)

# %%
model5.n_features_in_
# Out:
# 3

# %%
# The number of classes:
model5.n_classes_
# Out:
# 2

# %%
print(classification_report(y_test5,y_predicted5))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.61      0.69      0.65        29
#            1       0.70      0.62      0.66        34
#
#     accuracy                           0.65        63
#    macro avg       0.65      0.65      0.65        63
# weighted avg       0.66      0.65      0.65        63

# %%
cm5 = confusion_matrix(y_test5,y_predicted5)
sns.heatmap(cm5, annot=True,  linewidths=5, linecolor="red")
# Out:
# <AxesSubplot:>

# %%
fig = plt.figure(figsize=(100,50))
_ = tree.plot_tree(model5, feature_names=[0,1,2], class_names=True, filled=True, fontsize=45)
